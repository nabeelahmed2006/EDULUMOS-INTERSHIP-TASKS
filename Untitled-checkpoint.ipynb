# %%
import cv2

# %%
video_cap = cv2.VideoCapture(0)
while True :
    ret , video_data = video_cap.read()
    col = cv2.cvtColor(video_data,cv2.COLOR_BGR2GRAY)
    faces = face_cap.detectMultiscale(
        col,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(30,30),
        flags=cv2.CASCADE_SCALE_IMAGE
    )
    for (x,y,w,h) in faces:
        cv2.rectangle(video_data,(x,y),(x+w,y+h),(0,223,0),2)
     
    cv2.imshow("video_live",video_data)
    if cv2.waitkey(10) == ord("a"):
        break
    video_cap.release()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       3 ret , video_data = video_cap.read()
#       4 col = cv2.cvtColor(video_data,cv2.COLOR_BGR2GRAY)
# ----> 5 faces = face_cap.detectMultiscale(
#       6     col,
#       7     scaleFactor=1.1,
#       8     minNeighbors=5,
#       9     minSize=(30,30),
#      10     flags=cv2.CASCADE_SCALE_IMAGE
#      11 )
#      12 for (x,y,w,h) in faces:
#      13     cv2.rectangle(video_data,(x,y),(x+w,y+h),(0,223,0),2)
#
# NameError: name 'face_cap' is not defined
